# %%
import struct_post as sp

# %%
data = sp.read_lvm_file('6502.lvm')

# %%
data
# Out:
# (         Moog Force_kN  Moog Stroke_mm  LVDT 1_mm  LVDT 2_mm  LVDT 3_mm  \
#  X_Value
#  0.0          -0.093868     -238.599887  -0.008941  -0.004435   0.005930
#  0.5          -0.094941     -238.603320   0.002324  -0.003362   0.002175
#  1.0          -0.094405     -238.600423  -0.006259  -0.008458   0.000834
#  1.5          -0.093153     -238.600101   0.000983  -0.006580   0.005930
#  2.0          -0.091901     -238.601603  -0.003845  -0.003630  -0.000239
#  ...                ...             ...        ...        ...        ...
#  251.5        14.622519     -166.228304 -72.694128 -73.050110 -80.666339
#  252.0        14.628688     -166.233669 -72.691446 -73.055743 -80.668753
#  252.5        14.661680     -166.222833 -72.702174 -73.056279 -80.667948
#  253.0        14.530788     -166.212533 -72.705661 -73.057352 -80.679213
#  253.5        14.497528     -166.234312 -72.696274 -73.058693 -80.670362
#
#           LVDT 4_mm  LVDT 5_mm  LVDT 6_mm
#  X_Value
# ...

# %%
sp.beam.four_point_bending(data,63,150,1300
# Out:
# Sample Name: 6502
# ----------------------------------------
# ('6502',
#  {'E_app': np.float64(119.70187499203955),
#   'E_true': np.float64(101.08928715844398)})
