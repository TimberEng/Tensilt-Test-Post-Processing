# %%
import handcalcs.render

# %%
# %%render
# b = 50 #mm
# d = 300 #mm
# F_ult = 50000 #N
# L = 1200 #mm
# Out:
# \[
# \begin{aligned}
# b &= 50 \; \;\textrm{(mm)}
# \\[10pt]
# d &= 300 \; \;\textrm{(mm)}
# \\[10pt]
# F_{ult} &= 50000 \; \;\textrm{(N)}
# \\[10pt]
# L &= 1200 \; \;\textrm{(mm)}
# \end{aligned}
# \]

# %%
# %%render
# f_b = (F_ult * L) / (b * d **2) #MPa
# Out:
# \[
# \begin{aligned}
# f_{b} &= \frac{ F_{ult} \cdot L }{ b \cdot \left( d \right) ^{ 2 } }  = \frac{ 50000 \cdot 1200 }{ 50 \cdot \left( 300 \right) ^{ 2 } } &= 13.333 \; \;\textrm{(MPa)}
# \end{aligned}
# \]

# %%
# %%render
# delta_3 = 5
# delta_4 = 6
# delta_ms = delta_3 + delta_4 #mm
# Out:
# \[
# \begin{aligned}
# \delta_{3} &= 5 \;
# \\[10pt]
# \delta_{4} &= 6 \;
# \\[10pt]
# \delta_{ms} &= \delta_{3} + \delta_{4}  = 5 + 6 &= 11 \; \;\textrm{(mm)}
# \end{aligned}
# \]

# %%
# %%render
# delta_1 = 5
# delta_2 = 5
# delta_5 = 5
# delta_6 = 6
# delta_rel = delta_ms - (delta_1 + delta_2 + delta_5 + delta_6) / 4
# Out:
# \[
# \begin{aligned}
# \delta_{1} &= 5 \;
# \\[10pt]
# \delta_{2} &= 5 \;
# \\[10pt]
# \delta_{5} &= 5 \;
# \\[10pt]
# \delta_{6} &= 6 \;
# \\[10pt]
# \delta_{rel} &= \delta_{ms} - \frac{ \delta_{1} + \delta_{2} + \delta_{5} + \delta_{6} }{ 4 }  = 11 - \frac{ 5 + 5 + 5 + 6 }{ 4 } &= 5.750
# \end{aligned}
# \]

# %%
# %%render
# E_app = (23/108) * (L/d)**3 * Delta_ms * 1/b
# Out:
# \[
# \begin{aligned}
# E_{app} &= \left( \frac{ 23 }{ 108 } \right) \cdot \left( \frac{ L }{ d } \right) ^{ 3 } \cdot \delta_{ms} \cdot \frac{ 1 }{ b } \\&= \left( \frac{ 23 }{ 108 } \right) \cdot \left( \frac{ 1200 }{ 300 } \right) ^{ 3 } \cdot 11 \cdot \frac{ 1 }{ 50 } \\&= 2.999  \\[10pt]
# \end{aligned}
# \]

# %%
# %%render
# E_true = (1/36) *  (L/d)**3 * delta_rel * (1/b)
# Out:
# \[
# \begin{aligned}
# E_{true} &= \left( \frac{ 1 }{ 36 } \right) \cdot \left( \frac{ L }{ d } \right) ^{ 3 } \cdot \delta_{rel} \cdot \left( \frac{ 1 }{ b } \right) \\&= \left( \frac{ 1 }{ 36 } \right) \cdot \left( \frac{ 1200 }{ 300 } \right) ^{ 3 } \cdot 5.750 \cdot \left( \frac{ 1 }{ 50 } \right) \\&= 0.204  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ![image.png](attachment:3cb89233-ab94-4ce7-a4fe-6f39d846d735.png)
